# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\lokesh.s\\Downloads\\predict sales data\\Sales_November_2019.csv")
print(df)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       278797            Wired Headphones                1      11.99
# 1       278798        USB-C Charging Cable                2      11.95
# 2       278799    Apple Airpods Headphones                1      150.0
# 3       278800            27in FHD Monitor                1     149.99
# 4       278801  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 17656   295660      AAA Batteries (4-pack)                2       2.99
# 17657   295661        USB-C Charging Cable                1      11.95
# 17658   295662    Lightning Charging Cable                1      14.95
# 17659   295663      AAA Batteries (4-pack)                1       2.99
# 17660   295664                Google Phone                1        600
#
#            Order Date                      Purchase Address
# ...

# %%
df = df.dropna(how='all')
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       278797            Wired Headphones                1      11.99
# 1       278798        USB-C Charging Cable                2      11.95
# 2       278799    Apple Airpods Headphones                1      150.0
# 3       278800            27in FHD Monitor                1     149.99
# 4       278801  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 17656   295660      AAA Batteries (4-pack)                2       2.99
# 17657   295661        USB-C Charging Cable                1      11.95
# 17658   295662    Lightning Charging Cable                1      14.95
# 17659   295663      AAA Batteries (4-pack)                1       2.99
# 17660   295664                Google Phone                1        600
#
#            Order Date                      Purchase Address
# ...

# %%
df['Product'].value_counts()
# Out:
# Product
# USB-C Charging Cable          2062
# Lightning Charging Cable      2050
# AAA Batteries (4-pack)        2003
# AA Batteries (4-pack)         1974
# Wired Headphones              1787
# Apple Airpods Headphones      1499
# Bose SoundSport Headphones    1237
# 27in FHD Monitor               709
# iPhone                         663
# 27in 4K Gaming Monitor         578
# 34in Ultrawide Monitor         548
# Google Phone                   492
# Flatscreen TV                  458
# Macbook Pro Laptop             440
# 20in Monitor                   420
# ThinkPad Laptop                374
# Vareebadd Phone                177
# LG Dryer                        56
# LG Washing Machine              53
# Product                         36
# Name: count, dtype: int64

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       278797            Wired Headphones                1      11.99
# 1       278798        USB-C Charging Cable                2      11.95
# 2       278799    Apple Airpods Headphones                1      150.0
# 3       278800            27in FHD Monitor                1     149.99
# 4       278801  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 17656   295660      AAA Batteries (4-pack)                2       2.99
# 17657   295661        USB-C Charging Cable                1      11.95
# 17658   295662    Lightning Charging Cable                1      14.95
# 17659   295663      AAA Batteries (4-pack)                1       2.99
# 17660   295664                Google Phone                1        600
#
#            Order Date                      Purchase Address
# ...

# %%
index = df[df['Price Each'] == 'Price Each'].index[0]
print(index)
# Out:
# 1172

# %%
df = df.drop(1172)

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       278797            Wired Headphones                1      11.99
# 1       278798        USB-C Charging Cable                2      11.95
# 2       278799    Apple Airpods Headphones                1      150.0
# 3       278800            27in FHD Monitor                1     149.99
# 4       278801  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 17656   295660      AAA Batteries (4-pack)                2       2.99
# 17657   295661        USB-C Charging Cable                1      11.95
# 17658   295662    Lightning Charging Cable                1      14.95
# 17659   295663      AAA Batteries (4-pack)                1       2.99
# 17660   295664                Google Phone                1        600
#
#            Order Date                      Purchase Address
# ...

# %%
df['Price Each'].value_counts()
# Out:
# Price Each
# 11.95     2054
# 14.95     2047
# 2.99      1998
# 3.84      1973
# 11.99     1781
# 150       1491
# 99.99     1234
# 149.99     708
# 700        660
# 389.99     578
# 379.99     548
# 600        491
# 300        455
# 1700       439
# 109.99     420
# 999.99     374
# 400        176
# 600.0      109
# 150.0        7
# 700.0        3
# 300.0        2
# 400.0        1
# 1700.0       1
# Name: count, dtype: int64

# %%
date_format = '%m/%d/%y %H:%M'
df['datetime'] = pd.to_datetime(df['Order Date'], format=date_format)

# %%
df['date'] = df['datetime'].dt.date
df['time'] = df['datetime'].dt.time

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       278797            Wired Headphones                1      11.99
# 1       278798        USB-C Charging Cable                2      11.95
# 2       278799    Apple Airpods Headphones                1      150.0
# 3       278800            27in FHD Monitor                1     149.99
# 4       278801  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 17656   295660      AAA Batteries (4-pack)                2       2.99
# 17657   295661        USB-C Charging Cable                1      11.95
# 17658   295662    Lightning Charging Cable                1      14.95
# 17659   295663      AAA Batteries (4-pack)                1       2.99
# 17660   295664                Google Phone                1        600
#
#            Order Date                      Purchase Address  \
# ...

# %%
df = df.drop(columns=['datetime'])

# %%
df = df.drop(columns=['Order Date'])

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       278797            Wired Headphones                1      11.99
# 1       278798        USB-C Charging Cable                2      11.95
# 2       278799    Apple Airpods Headphones                1      150.0
# 3       278800            27in FHD Monitor                1     149.99
# 4       278801  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 17656   295660      AAA Batteries (4-pack)                2       2.99
# 17657   295661        USB-C Charging Cable                1      11.95
# 17658   295662    Lightning Charging Cable                1      14.95
# 17659   295663      AAA Batteries (4-pack)                1       2.99
# 17660   295664                Google Phone                1        600
#
#                            Purchase Address        date      time
# ...

# %%
df = df.drop('Street Address', axis=1)

# %%
if 'Street Address' in df.columns:
    df = df.drop(columns=['Street Address'])
else:
    print(f"Column '{'Street Address'}' does not exist in the DataFrame.")

# Print the resulting DataFrame
print(df)
# Out:
# Column 'Street Address' does not exist in the DataFrame.
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       278797            Wired Headphones                1      11.99
# 1       278798        USB-C Charging Cable                2      11.95
# 2       278799    Apple Airpods Headphones                1      150.0
# 3       278800            27in FHD Monitor                1     149.99
# 4       278801  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 17656   295660      AAA Batteries (4-pack)                2       2.99
# 17657   295661        USB-C Charging Cable                1      11.95
# 17658   295662    Lightning Charging Cable                1      14.95
# 17659   295663      AAA Batteries (4-pack)                1       2.99
# 17660   295664                Google Phone                1        600
#
# ...

# %%
df = df.drop('ZIP Code', axis=1)

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       278797            Wired Headphones                1      11.99
# 1       278798        USB-C Charging Cable                2      11.95
# 2       278799    Apple Airpods Headphones                1      150.0
# 3       278800            27in FHD Monitor                1     149.99
# 4       278801  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 17656   295660      AAA Batteries (4-pack)                2       2.99
# 17657   295661        USB-C Charging Cable                1      11.95
# 17658   295662    Lightning Charging Cable                1      14.95
# 17659   295663      AAA Batteries (4-pack)                1       2.99
# 17660   295664                Google Phone                1        600
#
#                            Purchase Address        date      time  \
# ...

# %%
df = df.drop('Purchase Address', axis=1)

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       278797            Wired Headphones                1      11.99
# 1       278798        USB-C Charging Cable                2      11.95
# 2       278799    Apple Airpods Headphones                1      150.0
# 3       278800            27in FHD Monitor                1     149.99
# 4       278801  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 17656   295660      AAA Batteries (4-pack)                2       2.99
# 17657   295661        USB-C Charging Cable                1      11.95
# 17658   295662    Lightning Charging Cable                1      14.95
# 17659   295663      AAA Batteries (4-pack)                1       2.99
# 17660   295664                Google Phone                1        600
#
#              date      time           City
# 0      2019-11-21  09:54:00  New York City
# ...

# %%
df.to_excel('november.xlsx', index=False)
