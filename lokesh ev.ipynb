# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\lokesh.s\\Downloads\\electric vehicle\\Electric_Vehicle_Population_Data.csv")
df
# Out:
#         VIN (1-10)        County               City State  Postal Code  \
# 0       KM8K33AGXL          King            Seattle    WA      98103.0
# 1       1C4RJYB61N          King            Bothell    WA      98011.0
# 2       1C4RJYD61P        Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA7J          King           Kirkland    WA      98034.0
# 4       WBY7Z8C5XJ      Thurston            Olympia    WA      98501.0
# ...            ...           ...                ...   ...          ...
# 150477  WBY43AW05P  Grays Harbor          Montesano    WA      98563.0
# 150478  5YJ3E1EB7P          King            Seattle    WA      98104.0
# 150479  5YJYGDEEXM          King            Seattle    WA      98109.0
# 150480  5UXTA6C08P     Snohomish  Mountlake Terrace    WA      98043.0
# 150481  7SAYGDEF8N        Skagit       Mount Vernon    WA      98273.0
#
#         Model Year     Make           Model  \
# 0             2020  HYUNDAI            KONA
# ...

# %%
 df["State"].value_counts()
# Out:
# State
# WA    150141
# CA        92
# VA        35
# MD        33
# TX        20
# NC        13
# IL        12
# AZ        11
# CO        11
# NJ         9
# FL         9
# OR         8
# HI         8
# CT         7
# NY         7
# SC         6
# NV         6
# GA         5
# DC         5
# MO         4
# NE         3
# KY         3
# MA         3
# LA         3
# AL         3
# KS         2
# ID         2
# WY         2
# OH         2
# AR         2
# BC         2
# PA         2
# IN         2
# UT         2
# MS         1
# MT         1
# DE         1
# NH         1
# AK         1
# AP         1
# MN         1
# Name: count, dtype: int64

# %%
 df["County"].value_counts()
# Out:
# County
# King          79075
# Snohomish     17307
# Pierce        11542
# Clark          8855
# Thurston       5403
#               ...
# Hennepin          1
# Maui              1
# Bell              1
# Portsmouth        1
# Suffolk           1
# Name: count, Length: 183, dtype: int64

# %%
df["City"].value_counts()
# Out:
# City
# Seattle          25675
# Bellevue          7691
# Redmond           5502
# Vancouver         5310
# Bothell           4861
#                  ...
# Coronado             1
# Suffolk              1
# Middletown           1
# Ewa Beach            1
# Ellicott City        1
# Name: count, Length: 683, dtype: int64

# %%
df["Model Year"].value_counts()
# Out:
# Model Year
# 2023    37079
# 2022    27799
# 2021    18684
# 2018    14441
# 2020    11294
# 2019    10717
# 2017     8574
# 2016     5650
# 2015     4934
# 2013     4566
# 2014     3613
# 2012     1633
# 2011      796
# 2024      642
# 2010       24
# 2008       19
# 2000        8
# 1999        4
# 2002        2
# 1998        1
# 2003        1
# 1997        1
# Name: count, dtype: int64

# %%
df["Base MSRP"].value_counts()
# Out:
# Base MSRP
# 0         147027
# 69900       1441
# 31950        399
# 52900        218
# 32250        152
# 59900        134
# 54950        133
# 39995        117
# 36900        101
# 44100         97
# 45600         84
# 64950         83
# 33950         74
# 52650         68
# 34995         64
# 36800         53
# 55700         50
# 53400         34
# 110950        21
# 90700         19
# 98950         19
# 81100         19
# 102000        17
# 75095         15
# 184400        11
# 43700         10
# 109000         7
# 89100          6
# 91250          5
# 32995          3
# 845000         1
# Name: count, dtype: int64

# %%
df = df.drop('VIN (1-10)', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = df.drop('VIN (1-10)', axis=1)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
df
# Out:
#               County               City State  Postal Code  Model Year  \
# 0               King            Seattle    WA      98103.0        2020
# 1               King            Bothell    WA      98011.0        2022
# 2             Yakima             Yakima    WA      98908.0        2023
# 3               King           Kirkland    WA      98034.0        2018
# 4           Thurston            Olympia    WA      98501.0        2018
# ...              ...                ...   ...          ...         ...
# 150477  Grays Harbor          Montesano    WA      98563.0        2023
# 150478          King            Seattle    WA      98104.0        2023
# 150479          King            Seattle    WA      98109.0        2021
# 150480     Snohomish  Mountlake Terrace    WA      98043.0        2023
# 150481        Skagit       Mount Vernon    WA      98273.0        2022
#
#            Make           Model                   Electric Vehicle Type  \
# ...

# %%
df = df.drop(['City','Postal Code','Base MSRP'], axis=1)

# %%
df
# Out:
#               County State  Model Year     Make           Model  \
# 0               King    WA        2020  HYUNDAI            KONA
# 1               King    WA        2022     JEEP  GRAND CHEROKEE
# 2             Yakima    WA        2023     JEEP  GRAND CHEROKEE
# 3               King    WA        2018    TESLA         MODEL 3
# 4           Thurston    WA        2018      BMW              I3
# ...              ...   ...         ...      ...             ...
# 150477  Grays Harbor    WA        2023      BMW              I4
# 150478          King    WA        2023    TESLA         MODEL 3
# 150479          King    WA        2021    TESLA         MODEL Y
# 150480     Snohomish    WA        2023      BMW              X5
# 150481        Skagit    WA        2022    TESLA         MODEL Y
#
#                          Electric Vehicle Type  \
# 0               Battery Electric Vehicle (BEV)
# 1       Plug-in Hybrid Electric Vehicle (PHEV)
# 2       Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %%
df = df.drop(['Legislative District','DOL Vehicle ID','Vehicle Location','2020 Census Tract'], axis=1)

# %%
df
# Out:
#               County State  Model Year     Make           Model  \
# 0               King    WA        2020  HYUNDAI            KONA
# 1               King    WA        2022     JEEP  GRAND CHEROKEE
# 2             Yakima    WA        2023     JEEP  GRAND CHEROKEE
# 3               King    WA        2018    TESLA         MODEL 3
# 4           Thurston    WA        2018      BMW              I3
# ...              ...   ...         ...      ...             ...
# 150477  Grays Harbor    WA        2023      BMW              I4
# 150478          King    WA        2023    TESLA         MODEL 3
# 150479          King    WA        2021    TESLA         MODEL Y
# 150480     Snohomish    WA        2023      BMW              X5
# 150481        Skagit    WA        2022    TESLA         MODEL Y
#
#                          Electric Vehicle Type  \
# 0               Battery Electric Vehicle (BEV)
# 1       Plug-in Hybrid Electric Vehicle (PHEV)
# 2       Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %%
df.to_excel('lokeshEV1.xlsx', index=False)
