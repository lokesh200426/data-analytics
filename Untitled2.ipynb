# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\lokesh.s\\Documents\\Household energy bill data origanl.csv")
df
# Out:
#      num_rooms  num_people  housearea  is_ac  is_tv  is_flat  \
# 0            3           3     742.57      1      1        1
# 1            1           5     952.99      0      1        0
# 2            3           1     761.44      1      1        1
# 3            0           5     861.32      1      1        0
# 4            1           8     731.61      0      1        0
# ..         ...         ...        ...    ...    ...      ...
# 995          3           0     991.31      0      1        0
# 996          2           5     847.97      0      1        0
# 997          2           4     660.94      1      0        0
# 998          1           1     814.75      0      1        1
# 999          1           6     835.43      0      0        0
#
#      ave_monthly_income  num_children  is_urban  amount_paid
# 0               9675.93             2         0   560.481447
# 1              35064.79             1         1   633.283679
# ...

# %%
df.ave_monthly_income.value_counts()
# Out:
# ave_monthly_income
# 22204.00    1
# 9675.93     1
# 35064.79    1
# 22292.44    1
# 12139.08    1
#            ..
# 22527.33    1
# 32341.30    1
# 13084.35    1
# 31430.75    1
# 28595.98    1
# Name: count, Length: 1000, dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.bar(list(df['num_people'].value_counts()),list(df['is_tv'].value_counts()),color="g")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 plt.figure(figsize=(10,10))
# ----> 2 plt.bar(list(df['num_people'].value_counts()),list(df['is_tv'].value_counts()),color="g")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2956, in bar(x, height, width, bottom, align, data, **kwargs)
#    2945 @_copy_docstring_and_deprecators(Axes.bar)
#    2946 def bar(
#    2947     x: float | ArrayLike,
#    (...)
#    2954     **kwargs,
#    2955 ) -> BarContainer:
# -> 2956     return gca().bar(
#    2957         x,
#    2958         height,
#    2959         width=width,
#    2960         bottom=bottom,
#    2961         align=align,
#    2962         **({"data": data} if data is not None else {}),
#    2963         **kwargs,
#    2964     )
#
# ...

# %%
df
# Out:
#      num_rooms  num_people  housearea  is_ac  is_tv  is_flat  \
# 0            3           3     742.57      1      1        1
# 1            1           5     952.99      0      1        0
# 2            3           1     761.44      1      1        1
# 3            0           5     861.32      1      1        0
# 4            1           8     731.61      0      1        0
# ..         ...         ...        ...    ...    ...      ...
# 995          3           0     991.31      0      1        0
# 996          2           5     847.97      0      1        0
# 997          2           4     660.94      1      0        0
# 998          1           1     814.75      0      1        1
# 999          1           6     835.43      0      0        0
#
#      ave_monthly_income  num_children  is_urban  amount_paid
# 0               9675.93             2         0   560.481447
# 1              35064.79             1         1   633.283679
# ...
