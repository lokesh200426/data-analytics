# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\lokesh.s\\Downloads\\predict sales data\\Sales_October_2019.csv')
print(df)
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       259358  34in Ultrawide Monitor                1     379.99
# 1       259359  27in 4K Gaming Monitor                1     389.99
# 2       259360  AAA Batteries (4-pack)                2       2.99
# 3       259361        27in FHD Monitor                1     149.99
# 4       259362        Wired Headphones                1      11.99
# ...        ...                     ...              ...        ...
# 20374   278792   AA Batteries (4-pack)                1       3.84
# 20375   278793        Wired Headphones                1      11.99
# 20376   278794   AA Batteries (4-pack)                1       3.84
# 20377   278795                  iPhone                1        700
# 20378   278796        Wired Headphones                1      11.99
#
#            Order Date                           Purchase Address
# 0      10/28/19 10:56            609 Cherry St, Dallas, TX 75001
# ...

# %%
df
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       259358  34in Ultrawide Monitor                1     379.99
# 1       259359  27in 4K Gaming Monitor                1     389.99
# 2       259360  AAA Batteries (4-pack)                2       2.99
# 3       259361        27in FHD Monitor                1     149.99
# 4       259362        Wired Headphones                1      11.99
# ...        ...                     ...              ...        ...
# 20374   278792   AA Batteries (4-pack)                1       3.84
# 20375   278793        Wired Headphones                1      11.99
# 20376   278794   AA Batteries (4-pack)                1       3.84
# 20377   278795                  iPhone                1        700
# 20378   278796        Wired Headphones                1      11.99
#
#            Order Date                           Purchase Address
# 0      10/28/19 10:56            609 Cherry St, Dallas, TX 75001
# ...

# %%
df = df.dropna(how='all')
df
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       259358  34in Ultrawide Monitor                1     379.99
# 1       259359  27in 4K Gaming Monitor                1     389.99
# 2       259360  AAA Batteries (4-pack)                2       2.99
# 3       259361        27in FHD Monitor                1     149.99
# 4       259362        Wired Headphones                1      11.99
# ...        ...                     ...              ...        ...
# 20374   278792   AA Batteries (4-pack)                1       3.84
# 20375   278793        Wired Headphones                1      11.99
# 20376   278794   AA Batteries (4-pack)                1       3.84
# 20377   278795                  iPhone                1        700
# 20378   278796        Wired Headphones                1      11.99
#
#            Order Date                           Purchase Address
# 0      10/28/19 10:56            609 Cherry St, Dallas, TX 75001
# ...

# %%
df['Product'].value_counts()
# Out:
# Product
# USB-C Charging Cable          2438
# Lightning Charging Cable      2412
# AA Batteries (4-pack)         2239
# AAA Batteries (4-pack)        2234
# Wired Headphones              2091
# Apple Airpods Headphones      1663
# Bose SoundSport Headphones    1437
# 27in FHD Monitor               789
# 27in 4K Gaming Monitor         718
# iPhone                         715
# 34in Ultrawide Monitor         671
# Google Phone                   597
# Macbook Pro Laptop             525
# Flatscreen TV                  523
# ThinkPad Laptop                459
# 20in Monitor                   426
# Vareebadd Phone                203
# LG Washing Machine              61
# LG Dryer                        50
# Product                          1
# Name: count, dtype: int64

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       259358  34in Ultrawide Monitor                1     379.99
# 1       259359  27in 4K Gaming Monitor                1     389.99
# 2       259360  AAA Batteries (4-pack)                2       2.99
# 3       259361        27in FHD Monitor                1     149.99
# 4       259362        Wired Headphones                1      11.99
# ...        ...                     ...              ...        ...
# 20374   278792   AA Batteries (4-pack)                1       3.84
# 20375   278793        Wired Headphones                1      11.99
# 20376   278794   AA Batteries (4-pack)                1       3.84
# 20377   278795                  iPhone                1        700
# 20378   278796        Wired Headphones                1      11.99
#
#            Order Date                           Purchase Address
# 0      10/28/19 10:56            609 Cherry St, Dallas, TX 75001
# ...

# %%
df['Product'].value_counts()
# Out:
# Product
# USB-C Charging Cable          2438
# Lightning Charging Cable      2412
# AA Batteries (4-pack)         2239
# AAA Batteries (4-pack)        2234
# Wired Headphones              2091
# Apple Airpods Headphones      1663
# Bose SoundSport Headphones    1437
# 27in FHD Monitor               789
# 27in 4K Gaming Monitor         718
# iPhone                         715
# 34in Ultrawide Monitor         671
# Google Phone                   597
# Macbook Pro Laptop             525
# Flatscreen TV                  523
# ThinkPad Laptop                459
# 20in Monitor                   426
# Vareebadd Phone                203
# LG Washing Machine              61
# LG Dryer                        50
# Product                          1
# Name: count, dtype: int64

# %%
index = df[df['Price Each'] == 'Price Each'].index[0]
print(index)
# Out:
# 521

# %%
df = df.drop(521)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df = df.drop(521)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       259358  34in Ultrawide Monitor                1     379.99
# 1       259359  27in 4K Gaming Monitor                1     389.99
# 2       259360  AAA Batteries (4-pack)                2       2.99
# 3       259361        27in FHD Monitor                1     149.99
# 4       259362        Wired Headphones                1      11.99
# ...        ...                     ...              ...        ...
# 20374   278792   AA Batteries (4-pack)                1       3.84
# 20375   278793        Wired Headphones                1      11.99
# 20376   278794   AA Batteries (4-pack)                1       3.84
# 20377   278795                  iPhone                1        700
# 20378   278796        Wired Headphones                1      11.99
#
#            Order Date                           Purchase Address
# 0      10/28/19 10:56            609 Cherry St, Dallas, TX 75001
# ...

# %%
df['Price Each'].value_counts()
# Out:
# Price Each
# 11.95     2438
# 14.95     2412
# 3.84      2239
# 2.99      2234
# 11.99     2091
# 150       1636
# 99.99     1437
# 149.99     789
# 389.99     718
# 700        704
# 379.99     671
# 600        587
# 1700       522
# 300        519
# 999.99     459
# 109.99     426
# 400        200
# 600.0      121
# 150.0       27
# 700.0       11
# 300.0        4
# 400.0        3
# 1700.0       3
# Name: count, dtype: int64

# %%
print(df['Order Date'].dtype)
# Out:
# object

# %%
date_format = '%m/%d/%y %H:%M'
df['datetime'] = pd.to_datetime(df['Order Date'], format=date_format)

# %%
df['date'] = df['datetime'].dt.date
df['time'] = df['datetime'].dt.time

# %%
df
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       259358  34in Ultrawide Monitor                1     379.99
# 1       259359  27in 4K Gaming Monitor                1     389.99
# 2       259360  AAA Batteries (4-pack)                2       2.99
# 3       259361        27in FHD Monitor                1     149.99
# 4       259362        Wired Headphones                1      11.99
# ...        ...                     ...              ...        ...
# 20374   278792   AA Batteries (4-pack)                1       3.84
# 20375   278793        Wired Headphones                1      11.99
# 20376   278794   AA Batteries (4-pack)                1       3.84
# 20377   278795                  iPhone                1        700
# 20378   278796        Wired Headphones                1      11.99
#
#            Order Date                           Purchase Address  \
# 0      10/28/19 10:56            609 Cherry St, Dallas, TX 75001
# ...

# %%
df = df.drop(columns=['datetime'])

# %%
df = df.drop(columns=['Order Date'])

# %%
df[['Street Address', 'City', 'ZIP Code']] = df['Purchase Address'].str.split(', ', expand=True)

# %%
df
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       259358  34in Ultrawide Monitor                1     379.99
# 1       259359  27in 4K Gaming Monitor                1     389.99
# 2       259360  AAA Batteries (4-pack)                2       2.99
# 3       259361        27in FHD Monitor                1     149.99
# 4       259362        Wired Headphones                1      11.99
# ...        ...                     ...              ...        ...
# 20374   278792   AA Batteries (4-pack)                1       3.84
# 20375   278793        Wired Headphones                1      11.99
# 20376   278794   AA Batteries (4-pack)                1       3.84
# 20377   278795                  iPhone                1        700
# 20378   278796        Wired Headphones                1      11.99
#
#                                 Purchase Address        date      time  \
# 0                609 Cherry St, Dallas, TX 75001  2019-10-28  10:56:00
# ...

# %%
df = df.drop('Street Address', axis=1)

# %%
if 'Street Address' in df.columns:
    df = df.drop(columns=['Street Address'])
else:
    print(f"Column '{'Street Address'}' does not exist in the DataFrame.")

# Print the resulting DataFrame
print(df)
# Out:
# Column 'Street Address' does not exist in the DataFrame.
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       259358  34in Ultrawide Monitor                1     379.99
# 1       259359  27in 4K Gaming Monitor                1     389.99
# 2       259360  AAA Batteries (4-pack)                2       2.99
# 3       259361        27in FHD Monitor                1     149.99
# 4       259362        Wired Headphones                1      11.99
# ...        ...                     ...              ...        ...
# 20374   278792   AA Batteries (4-pack)                1       3.84
# 20375   278793        Wired Headphones                1      11.99
# 20376   278794   AA Batteries (4-pack)                1       3.84
# 20377   278795                  iPhone                1        700
# 20378   278796        Wired Headphones                1      11.99
#
#                                 Purchase Address        date      time  \
# ...

# %%
df = df.drop('ZIP Code', axis=1)

# %%
df
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       259358  34in Ultrawide Monitor                1     379.99
# 1       259359  27in 4K Gaming Monitor                1     389.99
# 2       259360  AAA Batteries (4-pack)                2       2.99
# 3       259361        27in FHD Monitor                1     149.99
# 4       259362        Wired Headphones                1      11.99
# ...        ...                     ...              ...        ...
# 20374   278792   AA Batteries (4-pack)                1       3.84
# 20375   278793        Wired Headphones                1      11.99
# 20376   278794   AA Batteries (4-pack)                1       3.84
# 20377   278795                  iPhone                1        700
# 20378   278796        Wired Headphones                1      11.99
#
#                                 Purchase Address        date      time  \
# 0                609 Cherry St, Dallas, TX 75001  2019-10-28  10:56:00
# ...

# %%
df = df.drop('Purchase Address', axis=1)

# %%
df
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       259358  34in Ultrawide Monitor                1     379.99
# 1       259359  27in 4K Gaming Monitor                1     389.99
# 2       259360  AAA Batteries (4-pack)                2       2.99
# 3       259361        27in FHD Monitor                1     149.99
# 4       259362        Wired Headphones                1      11.99
# ...        ...                     ...              ...        ...
# 20374   278792   AA Batteries (4-pack)                1       3.84
# 20375   278793        Wired Headphones                1      11.99
# 20376   278794   AA Batteries (4-pack)                1       3.84
# 20377   278795                  iPhone                1        700
# 20378   278796        Wired Headphones                1      11.99
#
#              date      time           City
# 0      2019-10-28  10:56:00         Dallas
# 1      2019-10-28  17:26:00    Los Angeles
# ...

# %%
df.to_excel('october1.xlsx', index=False)
