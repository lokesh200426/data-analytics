# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\lokesh.s\\Downloads\\flipkart 5g phones\\5gPhones.csv")

# %%
df
# Out:
#      Unnamed: 0                                        name  \
# 0             1         vivo T2x 5G (Glimmer Black, 128 GB)
# 1             2           vivo T2x 5G (Aurora Gold, 128 GB)
# 2             3           vivo T2x 5G (Marine Blue, 128 GB)
# 3             4           vivo T2x 5G (Aurora Gold, 128 GB)
# 4             5           vivo T2x 5G (Marine Blue, 128 GB)
# ..          ...                                         ...
# 613         715     Tecno Phantom V fold 5G (Black, 256 GB)
# 614         716       OnePlus 11 5G (Eternal Green, 256 GB)
# 615         717    OnePlus Nord 2T 5G (Gray Shadow, 128 GB)
# 616         718    OnePlus Nord 2T 5G (Gray Shadow, 128 GB)
# 617         719  OnePlus 10 Pro 5G (Emerald Forest, 128 GB)
#
#      processed_battery  ram_processed  rom_processed  back_camera_processed  \
# 0                 5000              8            128                     50
# 1                 5000              8            128                     50
# ...

# %%
df = tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = tail()
#
# NameError: name 'tail' is not defined

# %%
df.tail()
# Out:
#      Unnamed: 0                                        name  \
# 613         715     Tecno Phantom V fold 5G (Black, 256 GB)
# 614         716       OnePlus 11 5G (Eternal Green, 256 GB)
# 615         717    OnePlus Nord 2T 5G (Gray Shadow, 128 GB)
# 616         718    OnePlus Nord 2T 5G (Gray Shadow, 128 GB)
# 617         719  OnePlus 10 Pro 5G (Emerald Forest, 128 GB)
#
#      processed_battery  ram_processed  rom_processed  back_camera_processed  \
# 613               5000             12            256                     50
# 614               5000             16            256                     50
# 615               4500              8            128                     50
# 616               4500              8            128                     50
# 617               5000              8            128                     48
#
#      front_camera_processed  screen_processed    brand  price_processed
# 613                     NaN             16.31    Tecno            88888
# ...

# %%
df['name'] = df['name'].str.replace(r"\(.*\)", "", regex=True)

# %%
df
# Out:
#      Unnamed: 0                      name  processed_battery  ram_processed  \
# 0             1              vivo T2x 5G                5000              8
# 1             2              vivo T2x 5G                5000              8
# 2             3              vivo T2x 5G                5000              6
# 3             4              vivo T2x 5G                5000              4
# 4             5              vivo T2x 5G                5000              4
# ..          ...                       ...                ...            ...
# 613         715  Tecno Phantom V fold 5G                5000             12
# 614         716            OnePlus 11 5G                5000             16
# 615         717       OnePlus Nord 2T 5G                4500              8
# 616         718       OnePlus Nord 2T 5G                4500              8
# 617         719        OnePlus 10 Pro 5G                5000              8
#
# ...

# %%
df['name'].value_counts()
# Out:
# name
# REDMI Note 12 5G                           12
# SAMSUNG Galaxy M33 5G                      12
# IQOO Z6 Lite 5G                            11
# REDMI Note 12 Pro 5G                       10
# REDMI Note 11T 5G                          10
#                                            ..
# SAMSUNG Galaxy S23 Ultra 5G Smartphone      1
# Tecno Camon 20 Pro                          1
# SAMSUNG A52s                                1
# REDMI Note 10 JE 5G                         1
# Tecno Phantom V fold 5G                     1
# Name: count, Length: 171, dtype: int64
